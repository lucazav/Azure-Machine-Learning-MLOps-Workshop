# %% [markdown]
# # Single-step pipeline examples
#
# In this example, we'll build a very simple pipeline that just contains a single train step. The dataset and compute cluster created in this tutorial will be re-used in the subsequent examples in this module.

# %%
# !pip install azureml-sdk --upgrade

# %%
import os
import azureml.core
from azureml.core import Workspace, Experiment, Dataset, RunConfiguration
from azureml.pipeline.core import Pipeline, PipelineData
from azureml.pipeline.steps import PythonScriptStep
from azureml.data.dataset_consumption_config import DatasetConsumptionConfig

print("Azure ML SDK version:", azureml.core.VERSION)
# Out:
# Azure ML SDK version: 1.20.0

# %% [markdown]
# First, we will connect to the workspace. The command `Workspace.from_config()` will either:
# * Read the local `config.json` with the workspace reference (given it is there) or
# * Use the `az` CLI to connect to the workspace and use the workspace attached to via `az ml folder attach -g <resource group> -w <workspace name>`

# %%
ws = Workspace.from_config()
print(f'WS name: {ws.name}\nRegion: {ws.location}\nSubscription id: {ws.subscription_id}\nResource group: {ws.resource_group}')
# Out:
# WS name: demo-ent-ws
# Region: westeurope
# Subscription id: bcbf34a7-1936-4783-8840-8f324c37f354
# Resource group: demo

# %% [markdown]
# # Preparation
#
# Let's quickly a create a compute cluster named `cluster`, in case it does not exist.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

aml_compute_target = "cluster"
try:
    aml_compute = AmlCompute(ws, aml_compute_target)
except ComputeTargetException:
    config = AmlCompute.provisioning_configuration(vm_size = "STANDARD_D2_V2", min_nodes = 0, max_nodes = 1,
                                                   idle_seconds_before_scaledown=3600)
    aml_compute = ComputeTarget.create(ws, aml_compute_target, config)
    aml_compute.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)

# %% [markdown]
# Furthermore, we'll create a new dataset and register it to the workspace. We'll be using this dataset also in the subsequent pipelines. If you already created this dataset, jump to the next cell.

# %%
from azureml.core import Dataset

datastore = ws.get_default_datastore()
datastore.upload(src_dir='../data-training', target_path='german-credit-train-tutorial', overwrite=True)
ds = Dataset.File.from_files(path=[(datastore, 'german-credit-train-tutorial')])
ds.register(ws, name='german-credit-train-tutorial', description='Dataset for workshop tutorials', create_new_version=True)

# %% [markdown]
# Next, let's reference our newly created training dataset, so that we can use it as the pipeline input:

# %%
training_dataset = Dataset.get_by_name(ws, "german-credit-train-tutorial")
# Download dataset to compute node - we can also use .as_mount() if the dataset does not fit the machine
training_dataset_consumption = DatasetConsumptionConfig("training_dataset", training_dataset).as_download()

# %% [markdown]
# Next, we can create a `PythonScriptStep` that runs our training code. In this case, we use a `runconfig` from a YAML file ([`runconfig.yml`](runconfig.yml)), that defines our training job (target compute cluster, conda environement, etc.) - have a look at it.

# %%
runconfig = RunConfiguration.load("runconfig.yml")

train_step = PythonScriptStep(name="train-step",
                        source_directory="./",
                        script_name="train.py",
                        arguments=['--data-path', training_dataset_consumption],
                        inputs=[training_dataset_consumption],
                        runconfig=runconfig,
                        allow_reuse=False)

steps = [train_step]

# %% [markdown]
# Finally, we can create our pipeline object and validate it. This will check the input and outputs are properly linked and that the pipeline graph is a non-cyclic graph:

# %%
pipeline = Pipeline(workspace=ws, steps=steps)
pipeline.validate()
# Out:
# Step train-step is ready to be created [e4b00fa2]
# []

# %% [markdown]
# Lastly, we can submit the pipeline against an experiment:

# %%
pipeline_run = Experiment(ws, 'mlops-workshop-pipelines').submit(pipeline)
pipeline_run.wait_for_completion()
# Out:
# Created step train-step [e4b00fa2][585717ca-65f0-4175-97d5-cfdb742ad49e], (This step will run and generate new outputs)
# Submitted PipelineRun 8e15e619-e240-4c45-8c20-614c55517286
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mlops-workshop-pipelines/runs/8e15e619-e240-4c45-8c20-614c55517286?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws
# PipelineRunId: 8e15e619-e240-4c45-8c20-614c55517286
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mlops-workshop-pipelines/runs/8e15e619-e240-4c45-8c20-614c55517286?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mlops-workshop-pipelines/runs/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws
# StepRun( train-step ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/01/19 09:08:09 Downloading source code...
# 2021/01/19 09:08:11 Finished downloading source code
# 2021/01/19 09:08:11 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/01/19 09:08:12 Successfully set up Docker network: acb_default_network
# 2021/01/19 09:08:12 Setting up Docker configuration...
# 2021/01/19 09:08:12 Successfully set up Docker configuration
# 2021/01/19 09:08:12 Logging in to registry: demoentwsb5fa738e.azurecr.io
# 2021/01/19 09:08:14 Successfully logged into demoentwsb5fa738e.azurecr.io
# 2021/01/19 09:08:14 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/19 09:08:14 Scanning for dependencies...
# 2021/01/19 09:08:14 Successfully scanned dependencies
# 2021/01/19 09:08:14 Launching container with name: acb_step_0
# Sending build context to Docker daemon  64.51kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# a1298f4ce990: Pull complete
# StepRun( train-step ) Status: Running
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in 1ccb7e14d10a
# Removing intermediate container 1ccb7e14d10a
#  ---> 2e7efecd967d
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 29d800026241
# Removing intermediate container 29d800026241
#  ---> 17bade3ea94c
# Step 4/15 : WORKDIR /
#  ---> Running in bd1adacac8bf
# Removing intermediate container bd1adacac8bf
#  ---> 1c74c109677a
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b4a47d6747fe
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 110c5b74a8d1
# Removing intermediate container 110c5b74a8d1
#  ---> bb20bd6ea594
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 2974b35a8323
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 6a5ee623324b
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# libgcc-ng-9.3.0      | 7.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 7.8 MB    | #####8     |  59%
# libgcc-ng-9.3.0      | 7.8 MB    | #######6   |  77%
# libgcc-ng-9.3.0      | 7.8 MB    | #########3 |  93%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
#
# zlib-1.2.11          | 106 KB    |            |   0%
# zlib-1.2.11          | 106 KB    | ########## | 100%
#
# readline-6.2         | 713 KB    |            |   0%
# readline-6.2         | 713 KB    | ########3  |  83%
# readline-6.2         | 713 KB    | ########## | 100%
#
# tk-8.5.19            | 1.9 MB    |            |   0%
# tk-8.5.19            | 1.9 MB    | #######7   |  78%
# tk-8.5.19            | 1.9 MB    | ########7  |  87%
# tk-8.5.19            | 1.9 MB    | #########5 |  96%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | #######5   |  76%
# openssl-1.0.2u       | 3.2 MB    | #########8 |  98%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# xz-5.2.5             | 343 KB    |            |   0%
# xz-5.2.5             | 343 KB    | #########4 |  95%
# xz-5.2.5             | 343 KB    | ########## | 100%
#
# ca-certificates-2020 | 137 KB    |            |   0%
# ca-certificates-2020 | 137 KB    | ########## | 100%
#
# certifi-2020.12.5    | 143 KB    |            |   0%
# certifi-2020.12.5    | 143 KB    | ########## | 100%
#
# libgomp-9.3.0        | 376 KB    |            |   0%
# libgomp-9.3.0        | 376 KB    | ########## | 100%
#
# wheel-0.36.2         | 31 KB     |            |   0%
# wheel-0.36.2         | 31 KB     | ########## | 100%
#
# ncurses-5.9          | 1.1 MB    |            |   0%
# ncurses-5.9          | 1.1 MB    | #######8   |  79%
# ncurses-5.9          | 1.1 MB    | ########6  |  86%
# ncurses-5.9          | 1.1 MB    | #########2 |  93%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# python-3.6.2         | 19.0 MB   |            |   0%
# python-3.6.2         | 19.0 MB   | ##2        |  23%
# python-3.6.2         | 19.0 MB   | #####9     |  60%
# python-3.6.2         | 19.0 MB   | #######5   |  75%
# python-3.6.2         | 19.0 MB   | ########8  |  88%
# python-3.6.2         | 19.0 MB   | #########7 |  98%
# python-3.6.2         | 19.0 MB   | ########## | 100%
#
# pip-20.2.4           | 1.1 MB    |            |   0%
# pip-20.2.4           | 1.1 MB    | ########   |  81%
# pip-20.2.4           | 1.1 MB    | #########5 |  95%
# pip-20.2.4           | 1.1 MB    | ########## | 100%
#
# setuptools-49.6.0    | 936 KB    |            |   0%
# setuptools-49.6.0    | 936 KB    | ########   |  80%
# setuptools-49.6.0    | 936 KB    | #########9 | 100%
# setuptools-49.6.0    | 936 KB    | ########## | 100%
#
# sqlite-3.13.0        | 4.9 MB    |            |   0%
# sqlite-3.13.0        | 4.9 MB    | #######5   |  76%
# sqlite-3.13.0        | 4.9 MB    | #########8 |  98%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.20.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[fuse,pandas]
#   Downloading azureml_dataprep-2.8.2-py3-none-any.whl (39.4 MB)
# Collecting scikit-learn==0.20.3
#   Downloading scikit_learn-0.20.3-cp36-cp36m-manylinux1_x86_64.whl (5.4 MB)
# Collecting pandas==0.25.3
#   Downloading pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Collecting joblib==0.13.2
#   Downloading joblib-0.13.2-py2.py3-none-any.whl (278 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.20.0
#   Downloading azureml_dataset_runtime-1.20.0-py3-none-any.whl (3.4 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-core~=1.20.0
#   Downloading azureml_core-1.20.0-py3-none-any.whl (2.1 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.7.0a,>=1.6.0dev0
#   Downloading azureml_dataprep_rslex-1.6.0-cp36-cp36m-manylinux2010_x86_64.whl (8.2 MB)
# Collecting azureml-dataprep-native<29.0.0,>=28.0.0
#   Downloading azureml_dataprep_native-28.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting numpy<2.0.0,>=1.14.0; extra == "pandas"
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting pyarrow<2.0.0,>=0.17.0; extra == "pandas"
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting scipy>=0.13.3
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting python-dateutil>=2.6.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.5-py2.py3-none-any.whl (510 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting six>=1.10
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting docker
#   Downloading docker-4.4.1-py2.py3-none-any.whl (146 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.5.0-py2.py3-none-any.whl (36 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.8.0-py2.py3-none-any.whl (58 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.10.0-py2.py3-none-any.whl (125 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/python3.6/site-packages (from requests>=2.17.3->azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.2r41a9e9.requirements.txt (line 1)) (2020.12.5)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=02b310b1cfc7676c75fbf310ea55e4811e70db8e21031e38601c335b6058ed69
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=78642ba6f5a1de900ba01f787a76bea109549ede510b6d6ec4c162cc988dfd9f
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=2b7c70fb49f0616021f87ea8cdb2f64c1a7f00f0a8c9332d57d53d403e05102f
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: configparser, werkzeug, itsdangerous, click, MarkupSafe, Jinja2, flask, json-logging-py, gunicorn, numpy, pyarrow, cloudpickle, portalocker, six, pycparser, cffi, cryptography, PyJWT, urllib3, idna, chardet, requests, msal, msal-extensions, azure-core, azure-identity, azureml-dataprep-rslex, azureml-dataprep-native, distro, dotnetcore2, fusepy, python-dateutil, pytz, pandas, azureml-dataprep, azureml-dataset-runtime, applicationinsights, dill, adal, liac-arff, azureml-model-management-sdk, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, pyopenssl, azure-common, azure-mgmt-containerregistry, backports.weakref, backports.tempfile, contextlib2, azure-mgmt-keyvault, ruamel.yaml.clib, ruamel.yaml, pyasn1, ndg-httpsclient, websocket-client, docker, jeepney, SecretStorage, azure-mgmt-storage, typing-extensions, zipp, importlib-metadata, jsonpickle, azure-graphrbac, jmespath, azure-mgmt-resource, pathspec, azure-mgmt-authorization, azureml-core, azureml-defaults, scipy, scikit-learn, joblib
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# azureml-dataset-runtime 1.20.0 requires azureml-dataprep<2.8.0a,>=2.7.0a, but you'll have azureml-dataprep 2.8.2 which is incompatible.
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 adal-1.2.5 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.10.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.20.0 azureml-dataprep-2.8.2 azureml-dataprep-native-28.0.0 azureml-dataprep-rslex-1.6.0 azureml-dataset-runtime-1.20.0 azureml-defaults-1.20.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.4 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.3.1 dill-0.3.3 distro-1.5.0 docker-4.4.1 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.4.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 joblib-0.13.2 json-logging-py-0.2 jsonpickle-1.5.0 liac-arff-2.5.0 msal-1.8.0 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.1.0 pandas-0.25.3 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.5 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 scikit-learn-0.20.3 scipy-1.5.4 six-1.15.0 typing-extensions-3.7.4.3 urllib3-1.26.2 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
#
# Removing intermediate container 6a5ee623324b
#  ---> 7b5e21f03f0f
# Step 9/15 : ENV PATH /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/bin:$PATH
#  ---> Running in f6793bfaf7fa
# Removing intermediate container f6793bfaf7fa
#  ---> d4e151a5bf28
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad
#  ---> Running in 8afa39f0ec2f
# Removing intermediate container 8afa39f0ec2f
#  ---> 805d821120cd
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib:$LD_LIBRARY_PATH
#  ---> Running in b07c0f3e7f5a
# Removing intermediate container b07c0f3e7f5a
#  ---> f048a9ea48f4
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 453287178892
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 734f581be90b
# Removing intermediate container 734f581be90b
#  ---> 5cb067899c95
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in e46a17cac76d
# Removing intermediate container e46a17cac76d
#  ---> 47711b7ebff1
# Step 15/15 : CMD ["bash"]
#  ---> Running in f60750d56ee1
# Removing intermediate container f60750d56ee1
#  ---> f792c128eddf
# Successfully built f792c128eddf
# Successfully tagged demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91:latest
# 2021/01/19 09:12:17 Successfully executed container: acb_step_0
# 2021/01/19 09:12:17 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/19 09:12:17 Pushing image: demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91:latest, attempt 1
# The push refers to repository [demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91]
# 0135a3a6b9fd: Preparing
# 01ed7a801ced: Preparing
# a3f8bb67df3b: Preparing
# 8514bd7be9e9: Preparing
# 4c28b7bd9b30: Preparing
# 73cf1421ce34: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 73cf1421ce34: Waiting
# a3f8bb67df3b: Pushed
# 0135a3a6b9fd: Pushed
# 8514bd7be9e9: Pushed
# 4c28b7bd9b30: Pushed
# 73cf1421ce34: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
#
# 340dc32eb998: Pushed
# 0e259b09e5f4: Pushed
# 85389f9ead9e: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# f2608f66a0e3: Pushed
#
# df18b66efaa6: Pushed
# 29f36b5893dc: Pushed
# 01ed7a801ced: Pushed
# latest: digest: sha256:036493314eb9df954dae7e4f412f3269a1de0e6ae06801fe94518fbb33300963 size: 3883
# 2021/01/19 09:13:54 Successfully pushed image: demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91:latest
# 2021/01/19 09:13:54 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 243.056059)
# 2021/01/19 09:13:54 Populating digests for step ID: acb_step_0...
# 2021/01/19 09:13:55 Successfully populated digests for step ID: acb_step_0
# 2021/01/19 09:13:55 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 97.084569)
# 2021/01/19 09:13:55 The following dependencies were found:
# 2021/01/19 09:13:55
# - image:
#     registry: demoentwsb5fa738e.azurecr.io
#     repository: azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91
#     tag: latest
#     digest: sha256:036493314eb9df954dae7e4f412f3269a1de0e6ae06801fe94518fbb33300963
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
#
# Run ID: cb12 was successful after 5m48s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3b58b23ebb37469ac1f07c2ab41fbc7f43557fb2270f063578cd53530d107746_d.txt
# ========================================================================================================================
# 2021-01-19T09:17:43Z Starting output-watcher...
# 2021-01-19T09:17:43Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-01-19T09:17:44Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-01-19T09:17:44Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# ec2c061b6e79: Pulling fs layer
# 45be97372f16: Pulling fs layer
# 741ed879c2f2: Pulling fs layer
# dcb42b399f96: Pulling fs layer
# c5158f856775: Pulling fs layer
# d584ef274e55: Waiting
# c445dda55407: Waiting
# baf7ab26f516: Waiting
# b177109c9d16: Waiting
# 699b75ff4717: Waiting
# 741ed879c2f2: Waiting
# 59cea07bb66c: Waiting
# 181182e3c9cf: Waiting
# d54d011de0e3: Waiting
# dcb42b399f96: Waiting
# c5158f856775: Waiting
# ec2c061b6e79: Waiting
# 45be97372f16: Waiting
# 05895bb28c18: Waiting
# 33b8b485aff0: Download complete
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# be8ec4e48d7f: Pull complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# 45be97372f16: Verifying Checksum
# 45be97372f16: Download complete
# 33b8b485aff0: Pull complete
# dcb42b399f96: Verifying Checksum
# dcb42b399f96: Download complete
# d887158cc58c: Pull complete
# 741ed879c2f2: Verifying Checksum
# 741ed879c2f2: Download complete
# c5158f856775: Verifying Checksum
# c5158f856775: Download complete
# 05895bb28c18: Pull complete
# ec2c061b6e79: Verifying Checksum
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# ec2c061b6e79: Pull complete
# 45be97372f16: Pull complete
# 741ed879c2f2: Pull complete
# dcb42b399f96: Pull complete
# c5158f856775: Pull complete
# Digest: sha256:96a223a2d683aab4b4f91719ba3f705a79883c430ca39e73845fd2ba36704f14
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30:latest
# viennaglobal.azurecr.io/azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30:latest
# 2021-01-19T09:18:23Z Check if container ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_3b58b23ebb37469ac1f07c2ab41fbc7f43557fb2270f063578cd53530d107746_d.txt
# ===============================================================================================================
# [2021-01-19T09:18:35.748220] Entering job preparation.
# [2021-01-19T09:18:36.588790] Starting job preparation.
# [2021-01-19T09:18:36.588827] Extracting the control code.
# [2021-01-19T09:18:36.616573] fetching and extracting the control code on master node.
# [2021-01-19T09:18:36.616613] Starting extract_project.
# [2021-01-19T09:18:36.616661] Starting to extract zip file.
# [2021-01-19T09:18:38.156163] Finished extracting zip file.
# [2021-01-19T09:18:38.349331] Using urllib.request Python 3.0 or later
# [2021-01-19T09:18:38.349412] Start fetching snapshots.
# [2021-01-19T09:18:38.349480] Start fetching snapshot.
# [2021-01-19T09:18:38.349499] Retrieving project from snapshot: 2194c1ae-958c-4883-bdf7-244de1662fd3
# Starting the daemon thread to refresh tokens in background for process with pid = 39
# [2021-01-19T09:18:41.031806] Finished fetching snapshot.
# [2021-01-19T09:18:41.031844] Finished fetching snapshots.
# [2021-01-19T09:18:41.031862] Finished extract_project.
# [2021-01-19T09:18:41.047033] Finished fetching and extracting the control code.
# [2021-01-19T09:18:41.052956] Start run_history_prep.
# [2021-01-19T09:18:41.312600] Job preparation is complete.
# [2021-01-19T09:18:41.312670] Entering Data Context Managers in Sidecar
# [2021-01-19T09:18:41.314350] Running Sidecar prep cmd...
# [2021-01-19T09:18:41.595564] DEBUG azureml.sidecar.try_add_control_script_to_path: Adding ES Control Scripts to sys.path: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/mounts/workspaceblobstore/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f-setup
# [2021-01-19T09:18:41.596486] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "enter_contexts"
# [2021-01-19T09:18:41.604400] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "exit_contexts"
# [2021-01-19T09:18:41.607373] DEBUG azureml.sidecar.set_run_wd: Changing working dir to: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/mounts/workspaceblobstore/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f
# [2021-01-19T09:18:41.607849] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/mounts/workspaceblobstore/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f
# [2021-01-19T09:18:41.608210] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2021-01-19T09:18:41.608637] DEBUG azureml.sidecar.TaskRegistry.execute: Executing "enter_contexts"
# [2021-01-19T09:18:41.609265] DEBUG azureml.sidecar.TaskServerClient.__init__: Connecting to TaskServer at 127.0.0.1:39533
# [2021-01-19T09:18:41.609747] DEBUG azureml.sidecar.TaskRegistry.execute: Sending payload for "enter_contexts":
# {"host_secret": "46e8adce-5fe5-43ef-b01a-11d368971669", "task": "enter_contexts", "caller_session_id": "f2d42105-90af-491b-8c3a-0e3016a54568", "context_managers": ["Dataset:context_managers.Datasets"], "job_task_error_path": "/mnt/batch/tasks/workitems/d2d15c4a-415b-4265-a99e-29d5f3b985b3/job-1/ebbc9dcb-3976-4d3f-a_f6823981-263d-4414-8309-a406e41961bf/wd/runSpecialJobTask_error.json"}
# [2021-01-19T09:18:47.980930] DEBUG azureml.sidecar.TaskRegistry.execute: Received response for "enter_contexts": {"result": "success"}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.19.0 azureml-dataprep==2.6.4. Session id: f7824c2f-af18-4985-9448-11d3207e571b. Run id: ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f.
# Processing 'training_dataset'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'german-credit-train-tutorial')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "73b4c537-e008-4d3c-8770-055011622520",
#     "name": "german-credit-train-tutorial",
#     "version": 1,
#     "description": "Dataset for workshop tutorials",
#     "workspace": "Workspace.create(name='demo-ent-ws', subscription_id='bcbf34a7-1936-4783-8840-8f324c37f354', resource_group='demo')"
#   }
# }
# Downloading training_dataset to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/wd/tmph6ncvdcu
# Downloaded training_dataset to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/wd/tmph6ncvdcu as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset training_dataset's target path to /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/wd/tmph6ncvdcu
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# [2021-01-19T09:18:47.957572] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-01-19T09:18:47.959044] DEBUG azureml.sidecar.task.enter_contexts: Added Keys: ['AZUREML_SIDECAR_PATHS_TO_BIND']
# [2021-01-19T09:18:47.966700] DEBUG azureml.sidecar.task.enter_contexts: Updated Keys: ['training_dataset', 'TRAINING_DATASET', 'AZUREML_DATAREFERENCE_training_dataset']
# [2021-01-19T09:18:47.968098] DEBUG azureml.sidecar.task.enter_contexts: Persisted env vars changed by ContextManagers
# [2021-01-19T09:18:47.969284] DEBUG azureml.sidecar.task.enter_contexts: Get File Access Control List for /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/wd/tmph6ncvdcu
# [2021-01-19T09:18:47.970263] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/wd/tmph6ncvdcu/german_credit_data.csv, ACL: 0o644, owner: root, group: root
# [2021-01-19T09:18:49.912934] Ran Sidecar prep cmd.
# [2021-01-19T09:18:49.912990] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/75_job_post-tvmps_3b58b23ebb37469ac1f07c2ab41fbc7f43557fb2270f063578cd53530d107746_d.txt
# ===============================================================================================================
# [2021-01-19T09:20:01.056439] Entering job release
# [2021-01-19T09:20:02.722926] Starting job release
# [2021-01-19T09:20:02.723741] Logging experiment finalizing status in history service.[2021-01-19T09:20:02.723914] job release stage : upload_datastore starting...
#
# Starting the daemon thread to refresh tokens in background for process with pid = 162
# [2021-01-19T09:20:02.724425] job release stage : start importing azureml.history._tracking in run_history_release.[2021-01-19T09:20:02.726457] job release stage : copy_batchai_cached_logs starting...
#
# [2021-01-19T09:20:02.734238] job release stage : execute_job_release starting...
# [2021-01-19T09:20:02.734686] job release stage : copy_batchai_cached_logs completed...
# [2021-01-19T09:20:02.797235] Entering context manager injector.
# [2021-01-19T09:20:02.918280] job release stage : upload_datastore completed...
# [2021-01-19T09:20:03.003338] job release stage : send_run_telemetry starting...
# [2021-01-19T09:20:03.165022] job release stage : execute_job_release completed...
# [2021-01-19T09:20:04.157987] job release stage : send_run_telemetry completed...
# Running in AzureML-Sidecar, starting to exit user context managers...
# Running Sidecar release cmd...
# [2021-01-19T09:20:04.165741] DEBUG azureml.sidecar.try_add_control_script_to_path: Adding ES Control Scripts to sys.path: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/mounts/workspaceblobstore/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f-setup
# [2021-01-19T09:20:04.167283] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "enter_contexts"
# [2021-01-19T09:20:04.175616] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "exit_contexts"
# [2021-01-19T09:20:04.179505] DEBUG azureml.sidecar.set_run_wd: Changing working dir to: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/mounts/workspaceblobstore/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f
# [2021-01-19T09:20:04.180012] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/mounts/workspaceblobstore/azureml/ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f
# [2021-01-19T09:20:04.180660] DEBUG azureml.sidecar.TaskRegistry.execute: Executing "exit_contexts"
# [2021-01-19T09:20:04.181299] DEBUG azureml.sidecar.TaskServerClient.__init__: Connecting to TaskServer at 127.0.0.1:39533
# [2021-01-19T09:20:04.181803] DEBUG azureml.sidecar.TaskRegistry.execute: Sending payload for "exit_contexts":
# {"host_secret": "46e8adce-5fe5-43ef-b01a-11d368971669", "task": "exit_contexts", "caller_session_id": "9de41b8c-acf0-423c-bcd8-dc2193d15028", "job_task_error_path": "/mnt/batch/tasks/workitems/d2d15c4a-415b-4265-a99e-29d5f3b985b3/job-1/ebbc9dcb-3976-4d3f-a_f6823981-263d-4414-8309-a406e41961bf/wd/runSpecialJobTask_error.json"}
# [2021-01-19T09:20:04.289340] DEBUG azureml.sidecar.TaskRegistry.execute: Received response for "exit_contexts": {"result": "success"}
# Enter __exit__ of DatasetContextManager
# Exit __exit__ of DatasetContextManager
# Removing absolute paths from host...
# [2021-01-19T09:20:04.280745] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# Ran Sidecar release cmd.
# [2021-01-19T09:20:05.321163] Job release is complete
# StepRun(train-step) Execution Summary
# ======================================
# StepRun( train-step ) Status: Finished
# {'runId': 'ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f', 'target': 'cluster', 'status': 'Completed', 'startTimeUtc': '2021-01-19T09:17:43.049641Z', 'endTimeUtc': '2021-01-19T09:20:13.784114Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '2194c1ae-958c-4883-bdf7-244de1662fd3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '585717ca-65f0-4175-97d5-cfdb742ad49e', 'azureml.nodeid': 'e4b00fa2', 'azureml.pipelinerunid': '8e15e619-e240-4c45-8c20-614c55517286', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '73b4c537-e008-4d3c-8770-055011622520'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_dataset', 'mechanism': 'Download'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--data-path', 'DatasetConsumptionConfig:training_dataset'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'cluster', 'dataReferences': {}, 'data': {'training_dataset': {'dataLocation': {'dataset': {'id': '73b4c537-e008-4d3c-8770-055011622520', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Download', 'environmentVariableName': 'training_dataset', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'Experiment mlops-workshop-pipelines Environment', 'version': 'Autosave_2021-01-19T09:08:04Z_74c2dced', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge', 'defaults'], 'dependencies': ['python=3.6.2', 'pip<20.3', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas,fuse]', 'scikit-learn==0.20.3', 'pandas==0.25.3', 'joblib==0.13.2']}], 'name': 'azureml_9cfcbdf246a71704d446a597691d2bad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.ebbc9dcb-3976-4d3f-ab08-c9a32ad1104f/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=w5cy9LzuWfZLSFfNZP9XarcmyZPrNSXMJYdDKB6Twug%3D&st=2021-01-19T09%3A10%3A07Z&se=2021-01-19T17%3A20%3A07Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_3b58b23ebb37469ac1f07c2ab41fbc7f43557fb2270f063578cd53530d107746_d.txt ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '8e15e619-e240-4c45-8c20-614c55517286', 'status': 'Completed', 'startTimeUtc': '2021-01-19T09:07:54.522925Z', 'endTimeUtc': '2021-01-19T09:20:24.393796Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.8e15e619-e240-4c45-8c20-614c55517286/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=KRc31AiqTFxT6jXINcTmmUxESMwXeU3OtDjLTiqz9t8%3D&st=2021-01-19T09%3A10%3A26Z&se=2021-01-19T17%3A20%3A26Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.8e15e619-e240-4c45-8c20-614c55517286/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=EmZ4byUrxlGHuPWXZmHjNY6clvxw0Ww8ohJkiW%2FFzwA%3D&st=2021-01-19T09%3A10%3A26Z&se=2021-01-19T17%3A20%3A26Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.8e15e619-e240-4c45-8c20-614c55517286/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=rtVS8W5pXqPfdu0TSLdnX5E7NJbF72JjXMQpMeI1xuI%3D&st=2021-01-19T09%3A10%3A26Z&se=2021-01-19T17%3A20%3A26Z&sp=r'}, 'submittedBy': 'Luca Zavarella'}
# 'Finished'

# %% [markdown]
# Alternatively, we can also publish the pipeline as a RESTful API Endpoint:

# %%
published_pipeline = pipeline.publish('mlops-training-pipeline')
published_pipeline
# Out:
# Pipeline(Name: mlops-training-pipeline,
# Id: 0d97563c-77e9-46a3-bf6d-47ca2d574946,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourceGroups/demo/providers/Microsoft.MachineLearningServices/workspaces/demo-ent-ws/PipelineRuns/PipelineSubmit/0d97563c-77e9-46a3-bf6d-47ca2d574946)

# %% [markdown]
# What if we want to continously publish a new pipelines, but have it published as the same URL as the version prior? For this, we can use [`PipelineEndpoint`](https://docs.microsoft.com/en-us/python/api/azureml-pipeline-core/azureml.pipeline.core.pipelineendpoint?view=azure-ml-py), which keeps multiple `PublishedPipeline`s behind a single endpoint URL. It allows to set `default_version`, which determines to which `PublishedPipeline` it should route the request.

# %%
from azureml.pipeline.core import PipelineEndpoint

endpoint_name = "mlops-training-pipeline-new"

# Try to find the upon defined endpoint name.
# If not exists, create a new endpoint with that name as deafult endpoint
try:
   pipeline_endpoint = PipelineEndpoint.get(workspace=ws, name=endpoint_name)
   # Add new default endpoint - only works from PublishedPipeline
   pipeline_endpoint.add_default(published_pipeline)
except Exception:
    pipeline_endpoint = PipelineEndpoint.publish(workspace=ws,
                                            name=endpoint_name,
                                            pipeline=pipeline,
                                            description="New Training Pipeline Endpoint")
