# %% [markdown]
# # Multi-step pipeline example
#
# In this example, we'll be building a two step pipeline which passes data from the a first step (prepare) to the second step (train).
#
# **Note:** This example requires that you've ran the notebook from the first tutorial, so that the dataset and compute cluster are set up.

# %%
import os
import azureml.core
from azureml.core import Workspace, Experiment, Dataset, RunConfiguration
from azureml.pipeline.core import Pipeline, PipelineData, PipelineParameter
from azureml.pipeline.steps import PythonScriptStep
from azureml.data.dataset_consumption_config import DatasetConsumptionConfig

print("Azure ML SDK version:", azureml.core.VERSION)
# Out:
# Azure ML SDK version: 1.28.0

# %% [markdown]
# First, we will connect to the workspace. The command `Workspace.from_config()` will either:
# * Read the local `config.json` with the workspace reference (given it is there) or
# * Use the `az` CLI to connect to the workspace and use the workspace attached to via `az ml folder attach -g <resource group> -w <workspace name>`

# %%
ws = Workspace.from_config()
print(f'WS name: {ws.name}\nRegion: {ws.location}\nSubscription id: {ws.subscription_id}\nResource group: {ws.resource_group}')
# Out:
# WS name: demo-ent-ws
# Region: westeurope
# Subscription id: bcbf34a7-1936-4783-8840-8f324c37f354
# Resource group: demo

# %% [markdown]
# Next, let's reference our training dataset from the last tutorial, so that we can use it as the pipeline input for the prepare step:

# %%
# Set our dataset as the default dataset (if user does not set the parameter during pipeline invocation)
default_training_dataset = Dataset.get_by_name(ws, "german-credit-train-tutorial")

# We're assigning passing the German dataset as default value of a PipelineParameter.
# This one can be set when submit a run of the Pipeline.
training_dataset_parameter = PipelineParameter(name="training_dataset", default_value=default_training_dataset)
training_dataset_consumption = DatasetConsumptionConfig("training_dataset", training_dataset_parameter).as_download()

# %% [markdown]
# Let's also define a `PipelineData` placeholder which will be used to persist and pipe data from the prepare step to the train step. The PipelineData name will be the blob storage's folder name containing the fist step's output data (*default storage --> azureml-blobstore-XXXXXXX... --> azureml --> step Run ID --> PipelineData name*):

# %%
default_datastore = ws.get_default_datastore()
prepared_data = PipelineData("prepared_data", datastore=default_datastore)

# %% [markdown]
# If you want to define a specific blob storage for the outputs, after defining it into the *Datastore*, you can use the Python [OutputFileDatasetConfig Class](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.data.output_dataset_config.outputfiledatasetconfig?view=azure-ml-py) ([here](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-move-data-in-out-of-pipelines#use-outputfiledatasetconfig-for-intermediate-data) some examples). It will be used in the next tutorial (*parallel_run_step_pipeline*).
#
# Next, we can create our two-stepped pipeline that runs some preprocessing on the data and then pipes the output to the training code. In this case, we use a separate `runconfig` for each step. The dependency graph is automatically resolved through the data input/outputs, but we could also define it ourselves (if desired):

# %%
prepare_runconfig = RunConfiguration.load("prepare_runconfig.yml")

prepare_step = PythonScriptStep(name="prepare-step",
                        runconfig=prepare_runconfig,
                        source_directory="./",
                        script_name=prepare_runconfig.script,
                        arguments=['--data-input-path', training_dataset_consumption,
                                   '--data-output-path', prepared_data],
                        inputs=[training_dataset_consumption],
                        outputs=[prepared_data],
                        allow_reuse=False)

train_runconfig = RunConfiguration.load("train_runconfig.yml")

train_step = PythonScriptStep(name="train-step",
                        runconfig=train_runconfig,
                        source_directory="./",
                        script_name=train_runconfig.script,
                        arguments=['--data-path', prepared_data],
                        inputs=[prepared_data],
                        allow_reuse=False)

train_step.run_after(prepare_step) # not really needed here, just for illustration
steps = [prepare_step, train_step]

# %% [markdown]
# Finally, we can create our pipeline object and validate it. This will check the input and outputs are properly linked and that the pipeline graph is a non-cyclic graph:

# %%
pipeline = Pipeline(workspace=ws, steps=steps)
pipeline.validate()
# Out:
# Step prepare-step is ready to be created [af65b269]
# Step train-step is ready to be created [0c2f9780]
# []

# %% [markdown]
# Lastly, we can submit the pipeline against an experiment:

# %%
pipeline_run = Experiment(ws, 'mlops-workshop-pipelines-20210524').submit(pipeline)
pipeline_run.wait_for_completion()
# Out:
# Created step prepare-step [af65b269][a5cd884e-449b-4691-8d1d-ef21cc0fbe5d], (This step will run and generate new outputs)Created step train-step [0c2f9780][1d830300-c223-46ed-91f3-966f4e06617e], (This step will run and generate new outputs)
#
# Submitted PipelineRun e972bea0-a7c8-4af0-8644-ca63beb52a63
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/e972bea0-a7c8-4af0-8644-ca63beb52a63?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws&tid=1f053027-5c7a-4f10-8444-ca55e5715f27
# PipelineRunId: e972bea0-a7c8-4af0-8644-ca63beb52a63
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/e972bea0-a7c8-4af0-8644-ca63beb52a63?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws&tid=1f053027-5c7a-4f10-8444-ca55e5715f27
# PipelineRun Status: Running
#
#
# StepRunId: 1976bc36-d674-4382-a3c8-f3336dfd807c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/1976bc36-d674-4382-a3c8-f3336dfd807c?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws&tid=1f053027-5c7a-4f10-8444-ca55e5715f27
# StepRun( prepare-step ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# ========================================================================================================================
# 2021-05-24T17:51:38Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore
# 2021-05-24T17:51:39Z Starting output-watcher...
# 2021-05-24T17:51:39Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-24T17:51:39Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-05-24T17:51:39Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# ac4e1c91b241: Pulling fs layer
# efb648489c68: Pulling fs layer
# e5e2bb35fef1: Pulling fs layer
# 41f64f9d12ca: Pulling fs layer
# 404e390f8ac9: Pulling fs layer
# 00d1c09f699a: Pulling fs layer
# 4c6ec688ebe3: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# e544ee0f522d: Waiting
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# ac4e1c91b241: Waiting
# efb648489c68: Waiting
# e5e2bb35fef1: Waiting
# 41f64f9d12ca: Waiting
# 404e390f8ac9: Waiting
# 00d1c09f699a: Waiting
# 0ba7bf18aa40: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 7e0ea9d0a1ab: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# da005f826951: Download complete
# ac4e1c91b241: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# e5e2bb35fef1: Verifying Checksum
# e5e2bb35fef1: Download complete
# 4007a89234b4: Pull complete
# 404e390f8ac9: Verifying Checksum
# 404e390f8ac9: Download complete
# 41f64f9d12ca: Verifying Checksum
# 41f64f9d12ca: Download complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 00d1c09f699a: Verifying Checksum
# 00d1c09f699a: Download complete
# 4c6ec688ebe3: Pull complete
# efb648489c68: Verifying Checksum
# efb648489c68: Download complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# ac4e1c91b241: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# ===============================================================================================================
# [2021-05-24T17:52:01.467024] Entering job preparation.
# [2021-05-24T17:52:02.208285] Starting job preparation.
# [2021-05-24T17:52:02.208330] Extracting the control code.
# [2021-05-24T17:52:02.232051] fetching and extracting the control code on master node.
# [2021-05-24T17:52:02.232101] Starting extract_project.
# [2021-05-24T17:52:02.232160] Starting to extract zip file.
# [2021-05-24T17:52:02.856812] Finished extracting zip file.
# [2021-05-24T17:52:03.026230] Using urllib.request Python 3.0 or later
# [2021-05-24T17:52:03.026327] Start fetching snapshots.
# [2021-05-24T17:52:03.026377] Start fetching snapshot.
# [2021-05-24T17:52:03.026410] Retrieving project from snapshot: e5c616eb-c2ae-44f5-94bf-41c9f196635c
# Starting the daemon thread to refresh tokens in background for process with pid = 42
# [2021-05-24T17:52:03.999870] Finished fetching snapshot.
# [2021-05-24T17:52:03.999908] Finished fetching snapshots.
# [2021-05-24T17:52:03.999948] Finished extract_project.
# [2021-05-24T17:52:04.013991] Finished fetching and extracting the control code.
# [2021-05-24T17:52:04.021988] Start run_history_prep.
# [2021-05-24T17:52:04.084927] Job preparation is complete.
# [2021-05-24T17:52:04.085099] Entering Data Context Managers in Sidecar
# [2021-05-24T17:52:04.085916] Running Sidecar prep cmd...
# [2021-05-24T17:52:04.711220] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c
# [2021-05-24T17:52:04.712306] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.26.0 azureml-dataprep==2.14.2. Session id: 17997958-0a20-403b-9598-6e0c6924f929. Run id: 1976bc36-d674-4382-a3c8-f3336dfd807c.
# Processing 'training_dataset'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'german-credit-train-tutorial')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "73b4c537-e008-4d3c-8770-055011622520",
#     "name": "german-credit-train-tutorial",
#     "version": 1,
#     "description": "Dataset for workshop tutorials",
#     "workspace": "Workspace.create(name='demo-ent-ws', subscription_id='bcbf34a7-1936-4783-8840-8f324c37f354', resource_group='demo')"
#   }
# }
# Downloading training_dataset to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/wd/tmpg84pw8up
# Downloaded training_dataset to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/wd/tmpg84pw8up as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset training_dataset's target path to /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/wd/tmpg84pw8up
# Sidecar adding paths_to_bind: ['/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/wd/tmpcv8hu11u:/tmp/c9c23e1c-b36e-4a4f-8ec8-f7bc67d28da8/3375b36d-a98d-4648-b191-6b0ea4223777']
# Acquired lockfile /tmp/1976bc36-d674-4382-a3c8-f3336dfd807c-datastore.lock to downloading input data references
# [2021-05-24T17:52:10.513152] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-05-24T17:52:10.954496] Ran Sidecar prep cmd.
# [2021-05-24T17:52:10.954614] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# bash: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/05/24 17:52:33 Starting App Insight Logger for task:  runTaskLet
# 2021/05/24 17:52:33 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# bash: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/05/24 17:52:33 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-05-24T17:52:34.115362] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prepare.py', '--data-input-path', 'DatasetConsumptionConfig:training_dataset', '--data-output-path', '/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/prepared_data'])
# Script type = None
# [2021-05-24T17:52:35.577320] Entering Run History Context Manager.
# [2021-05-24T17:52:36.229404] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c
# [2021-05-24T17:52:36.229805] Preparing to call script [prepare.py] with arguments:['--data-input-path', '$training_dataset', '--data-output-path', '/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/prepared_data']
# [2021-05-24T17:52:36.229959] After variable expansion, calling script [prepare.py] with arguments:['--data-input-path', '/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/wd/tmpg84pw8up', '--data-output-path', '/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/prepared_data']
#
# Reading data from /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/wd/tmpg84pw8up/german_credit_data.csv and writing processed output to /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/prepared_data/german_credit_data.csv
# Output dir: []
#
#
# [2021-05-24T17:52:36.530564] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 1 items cleaning up...
# Cleanup took 0.07684206962585449 seconds
# [2021-05-24T17:52:36.856398] Finished context manager injector.
# 2021/05/24 17:52:37 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/05/24 17:52:37 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 3
# FilteredData: 0.
# 2021/05/24 17:52:37 Process Exiting with Code:  0
# 2021/05/24 17:52:38 All App Insights Logs was send successfully
# Streaming azureml-logs/75_job_post-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# ===============================================================================================================
# [2021-05-24T17:52:39.551421] Entering job release
# [2021-05-24T17:52:41.231670] Starting job release
# [2021-05-24T17:52:41.232462] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 163
# [2021-05-24T17:52:41.234982] job release stage : upload_datastore starting...
# [2021-05-24T17:52:41.245965] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-24T17:52:41.246032] job release stage : execute_job_release starting...
# [2021-05-24T17:52:41.246608] job release stage : copy_batchai_cached_logs starting...
# [2021-05-24T17:52:41.246727] job release stage : copy_batchai_cached_logs completed...
# [2021-05-24T17:52:41.317565] Entering context manager injector.
# [2021-05-24T17:52:41.343936] job release stage : send_run_telemetry starting...
# [2021-05-24T17:52:41.372305] job release stage : upload_datastore completed...
# [2021-05-24T17:52:41.389347] job release stage : execute_job_release completed...
# [2021-05-24T17:52:41.551176] get vm size and vm region successfully.
# [2021-05-24T17:52:41.570344] get compute meta data successfully.
# [2021-05-24T17:52:41.932976] post artifact meta request successfully.
# [2021-05-24T17:52:41.969131] upload compute record artifact successfully.
# [2021-05-24T17:52:41.969243] job release stage : send_run_telemetry completed...
# [2021-05-24T17:52:41.969933] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-05-24T17:52:41.970143] Running Sidecar release cmd...
# [2021-05-24T17:52:41.981753] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/mounts/workspaceblobstore/azureml/1976bc36-d674-4382-a3c8-f3336dfd807c
# Enter __exit__ of DatasetContextManager
# Exit __exit__ of DatasetContextManager
# [2021-05-24T17:52:42.016078] Removing absolute paths from host...
# [2021-05-24T17:52:42.023780] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-05-24T17:52:43.020068] Ran Sidecar release cmd.
# [2021-05-24T17:52:43.020196] Job release is complete
#
# StepRun(prepare-step) Execution Summary
# ========================================
# StepRun( prepare-step ) Status: Finished
# {'runId': '1976bc36-d674-4382-a3c8-f3336dfd807c', 'target': 'cluster', 'status': 'Completed', 'startTimeUtc': '2021-05-24T17:51:36.583843Z', 'endTimeUtc': '2021-05-24T17:52:54.385686Z', 'properties': {'ContentSnapshotId': 'e5c616eb-c2ae-44f5-94bf-41c9f196635c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'a5cd884e-449b-4691-8d1d-ef21cc0fbe5d', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'af65b269', 'azureml.pipelinerunid': 'e972bea0-a7c8-4af0-8644-ca63beb52a63', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '73b4c537-e008-4d3c-8770-055011622520'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_dataset', 'mechanism': 'Download'}}], 'outputDatasets': [], 'runDefinition': {'script': 'prepare.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--data-input-path', 'DatasetConsumptionConfig:training_dataset', '--data-output-path', '$AZUREML_DATAREFERENCE_prepared_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'cluster', 'dataReferences': {'prepared_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/prepared_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'training_dataset': {'dataLocation': {'dataset': {'id': '73b4c537-e008-4d3c-8770-055011622520', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Download', 'environmentVariableName': 'training_dataset', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment mlops-workshop-pipelines-20210524 Environment', 'version': 'Autosave_2021-05-24T15:14:27Z_2c4b275f', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge', 'defaults'], 'dependencies': ['python=3.6.2', 'pip<20.3', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas,fuse]', 'scikit-learn==0.20.3', 'pandas==0.25.3', 'joblib==0.13.2']}], 'name': 'azureml_9cfcbdf246a71704d446a597691d2bad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': ...
# StepRunId: 56a05f73-be56-4f4e-a605-b2e8e9d3bab6
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/56a05f73-be56-4f4e-a605-b2e8e9d3bab6?wsid=/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourcegroups/demo/workspaces/demo-ent-ws&tid=1f053027-5c7a-4f10-8444-ca55e5715f27
# StepRun( train-step ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# ========================================================================================================================
# 2021-05-24T17:53:07Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore
# 2021-05-24T17:53:08Z Starting output-watcher...
# 2021-05-24T17:53:08Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-24T17:53:08Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-05-24T17:53:08Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91
# Digest: sha256:036493314eb9df954dae7e4f412f3269a1de0e6ae06801fe94518fbb33300963
# Status: Image is up to date for demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91:latest
# demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91:latest
# 2021-05-24T17:53:09Z Check if container 56a05f73-be56-4f4e-a605-b2e8e9d3bab6 already exist exited with 0,
#
# 018cacf10fba86437e81507de69d609875878e29958206cade3aef8de8e69409
# 2021-05-24T17:53:09Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-05-24T17:53:09Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-a271f132e67c01f3117d1bb721023495-3c5d96133d66975e-01 -sshRequired=false]
# 2021/05/24 17:53:09 Starting App Insight Logger for task:  containerSetup
# 2021/05/24 17:53:09 Version: 3.0.01593.0001 Branch: 2021-05-13 Commit: 960e76c
# 2021/05/24 17:53:09 Entered ContainerSetupTask - Preparing infiniband
# 2021/05/24 17:53:09 Starting infiniband setup
# 2021/05/24 17:53:09 Python Version found is bash: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so.5: no version information available (required by bash)
# Python 3.6.2
#
# 2021/05/24 17:53:09 Returning Python Version as /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so
# 2021/05/24 17:53:09 VMSize: standard_ds3_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/24 17:53:09 VMSize: standard_ds3_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-05-24T17:53:09Z VMSize: standard_ds3_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/24 17:53:09 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/05/24 17:53:09 Not setting up Infiniband in Container
# 2021/05/24 17:53:09 Not setting up Infiniband in Container
# 2021-05-24T17:53:09Z Not setting up Infiniband in Container
# 2021/05/24 17:53:09 Python Version found is bash: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so.5: no version information available (required by bash)
# Python 3.6.2
#
# 2021/05/24 17:53:09 Returning Python Version as /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so
# 2021/05/24 17:53:09 sshd inside container not required for job, skipping setup.
# 2021/05/24 17:53:10 All App Insights Logs was send successfully
# 2021/05/24 17:53:10 App Insight Client has already been closed
# 2021/05/24 17:53:10 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-05-24T17:53:10Z Starting docker container succeeded.
# 2021-05-24T17:53:14Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2021/05/24 17:53:06 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/05/24 17:53:06 Version: 3.0.01593.0001 Branch: 2021-05-13 Commit: 960e76c
# >>>   2021/05/24 17:53:06 runtime.GOOS linux
# >>>   2021/05/24 17:53:06 Checking if '/tmp' exists
# >>>   2021/05/24 17:53:06 Reading dyanamic configs
# >>>   2021/05/24 17:53:06 Container sas url: https://baiscriptswesteuropeprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=9UBH7ig8b9NIeIkNQpNxDmP7wUMtSqFoIE5AY22cheE%3D
# >>>   2021/05/24 17:53:06 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2021/05/24 17:53:06 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installer on host: false. Is Azsecpack enabled: false,
# >>>   2021/05/24 17:53:06 Starting Azsecpack installation on machine: 759e33a34caf4f0c8027917e0e134750000001#1f053027-5c7a-4f10-8444-ca55e5715f27#bcbf34a7-1936-4783-8840-8f324c37f354#demo#demo-ent-ws#cluster
# >>>   2021/05/24 17:53:06 Is Azsecpack enabled: false, GetDisableVsatlsscan: true
# >>>   2021/05/24 17:53:06 Turning off azsecpack, if it is already running
# >>>   2021/05/24 17:53:06 [doTurnOffAzsecpack] output:Unit mdsd.service could not be found.
# >>>   ,err:exit status 1.
# >>>   2021/05/24 17:53:06 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/05/24 17:53:06 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/05/24 17:53:06 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/24 17:53:06 GPU count found on the node: 0
# >>>   2021/05/24 17:53:06 AMLComputeXDSEndpoint:  https://westeurope-prodk8ds.batchai.core.windows.net
# >>>   2021/05/24 17:53:06 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/05/24 17:53:06 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config
# >>>   2021/05/24 17:53:06 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/05/24 17:53:06 Starting identity responder.
# >>>   2021/05/24 17:53:06 Starting identity responder.
# >>>   2021/05/24 17:53:06 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/05/24 17:53:06 Logfile used for identity responder: /mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/IdentityResponderLog-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# >>>   2021/05/24 17:53:06 Logfile used for identity responder: /mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/IdentityResponderLog-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# >>>   2021/05/24 17:53:06 Started Identity Responder for job.
# >>>   2021/05/24 17:53:06 Started Identity Responder for job.
# >>>   2021/05/24 17:53:06 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/wd
# >>>   2021/05/24 17:53:06 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/shared
# >>>   2021/05/24 17:53:06 From the policy service, the filtering patterns is: , data store is
# >>>   2021/05/24 17:53:06 Mounting job level file systems
# >>>   2021/05/24 17:53:06 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts
# >>>   2021/05/24 17:53:06 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.amlcompute.datastorecredentials
# >>>   2021/05/24 17:53:06 Datastore credentials file not found, skipping.
# >>>   2021/05/24 17:53:06 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.master.runtimesastokens
# >>>   2021/05/24 17:53:06 Runtime sas tokens file not found, skipping.
# >>>   2021/05/24 17:53:06 No NFS configured
# >>>   2021/05/24 17:53:06 No Azure File Shares configured
# >>>   2021/05/24 17:53:06 Mounting blob file systems
# >>>   2021/05/24 17:53:06 Blobfuse runtime version 1.3.6
# >>>   2021/05/24 17:53:06 Mounting azureml-blobstore-59572a34-8b6b-434e-8830-2449a3132240 container from demoentws5367325393 account at /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore
# >>>   2021/05/24 17:53:06 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/05/24 17:53:06 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/05/24 17:53:06 Blobfuse cache size set to 21336 MB.
# >>>   2021/05/24 17:53:06 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=21336 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/05/24 17:53:06 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore
# >>>   2021/05/24 17:53:07 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore
# >>>   2021/05/24 17:53:07 Successfully mounted azureml-blobstore-59572a34-8b6b-434e-8830-2449a3132240 container from demoentws5367325393 account at /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore
# >>>   2021/05/24 17:53:07 Created run_id directory: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6
# >>>   2021/05/24 17:53:07 No unmanaged file systems configured
# >>>   2021/05/24 17:53:07 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/24 17:53:07 From the policy service, the filtering patterns is: , data store is
# >>>   2021/05/24 17:53:07 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs
# >>>   2021/05/24 17:53:07 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/logs
# >>>   2021/05/24 17:53:08 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/outputs
# >>>   2021/05/24 17:53:08 Starting output-watcher...
# >>>   2021/05/24 17:53:08 Single file input dataset is enabled.
# >>>   2021/05/24 17:53:08 Start to pulling docker image: demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91
# >>>   2021/05/24 17:53:08 Start pull docker image: demoentwsb5fa738e.azurecr.io
# >>>   2021/05/24 17:53:08 Getting credentials for image demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91 with url demoentwsb5fa738e.azurecr.io
# >>>   2021/05/24 17:53:08 Container registry is ACR.
# >>>   2021/05/24 17:53:08 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/05/24 17:53:08 Getting ACR Credentials from EMS for environment Experiment mlops-workshop-pipelines-20210524 Environment:Autosave_2021-05-24T15:14:27Z_2c4b275f
# >>>   2021/05/24 17:53:08 Requesting XDS for registry details.
# >>>   2021/05/24 17:53:08 Attempt 1 of http call to https://westeurope-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourceGroups/demo/workspaces/demo-ent-ws/clusters/cluster/nodes/tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d?api-version=2018-02-01
# >>>   2021/05/24 17:53:08 Got container registry details from credentials service for registry address: demoentwsb5fa738e.azurecr.io.
# >>>   2021/05/24 17:53:08 Writing ACR Details to file...
# >>>   2021/05/24 17:53:08 Copying ACR Details file to worker nodes...
# >>>   2021/05/24 17:53:08 Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2021/05/24 17:53:08 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/05/24 17:53:08 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/05/24 17:53:08 Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/05/24 17:53:08 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/05/24 17:53:08 EMS returned demoentwsb5fa738e.azurecr.io for environment Experiment mlops-workshop-pipelines-20210524 Environment
# >>>   2021/05/24 17:53:08 Save docker credentials for image demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91 in /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/wd/docker_login_897F80703DCA120B
# >>>   2021/05/24 17:53:08 start login to the docker registry
# >>>   2021/05/24 17:53:08 Successfully logged into the docker registry.
# >>>   2021/05/24 17:53:08 Start run pull docker image command
# >>>   2021/05/24 17:53:09 Pull docker image succeeded.
# >>>   2021/05/24 17:53:09 Removed docker config dir /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/wd/docker_login_897F80703DCA120B
# >>>   2021/05/24 17:53:09 Pull docker image time: 908.930746ms
# >>>
# >>>   2021/05/24 17:53:09 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/05/24 17:53:09 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/24 17:53:09 Setting the memory limit for docker container to be 13674 MB
# >>>   2021/05/24 17:53:09 The env variable file size is 39972 bytes
# >>>   2021/05/24 17:53:09 Creating parent cgroup '56a05f73-be56-4f4e-a605-b2e8e9d3bab6' for Containers used in Job
# >>>   2021/05/24 17:53:09 Add parent cgroup '56a05f73-be56-4f4e-a605-b2e8e9d3bab6' to container '56a05f73-be56-4f4e-a605-b2e8e9d3bab6'
# >>>   2021/05/24 17:53:09 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/05/24 17:53:09 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,56a05f73-be56-4f4e-a605-b2e8e9d3bab6,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/certs:/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,13674m,-v,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd:/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6:/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.batchai.envlist,--cgroup-parent=/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/,--shm-size,2g
# >>>   2021/05/24 17:53:09 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/05/24 17:53:09 the binding /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6:/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6
# >>>   2021/05/24 17:53:09 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,56a05f73-be56-4f4e-a605-b2e8e9d3bab6,-m,13674m,-w,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.batchai.envlist,--cgroup-parent=/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/,--shm-size,2g,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6:/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6,-v,/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd:/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd,-v,/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/certs:/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/certs
# >>>   2021/05/24 17:53:09 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 56a05f73-be56-4f4e-a605-b2e8e9d3bab6 -m 13674m -w /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/config/.batchai.envlist --cgroup-parent=/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/ --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6:/mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6 -v /mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd:/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd -v /mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/certs:/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/certs -d -it --privileged --net=host demoentwsb5fa738e.azurecr.io/azureml/azureml_2e16031b3872f79cf3d953cc9fca1d91
# >>>   2021/05/24 17:53:09 Check if container 56a05f73-be56-4f4e-a605-b2e8e9d3bab6 already exist exited with 0,
# >>>
# >>>   2021/05/24 17:53:09 Check if container 56a05f73-be56-4f4e-a605-b2e8e9d3bab6 already exist exited with 0,
# >>>
# >>>   2021/05/24 17:53:09 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/24 17:53:09 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/24 17:53:09 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-a271f132e67c01f3117d1bb721023495-3c5d96133d66975e-01 -sshRequired=false]
# >>>   2021/05/24 17:53:09 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-a271f132e67c01f3117d1bb721023495-3c5d96133d66975e-01 -sshRequired=false]
# >>>   2021/05/24 17:53:10 Container ssh is not required for job type.
# >>>   2021/05/24 17:53:10 Starting docker container succeeded.
# >>>   2021/05/24 17:53:10 Starting docker container succeeded.
# >>>   2021/05/24 17:53:10 Disk space after starting docker container: 22790MB
# >>>   2021/05/24 17:53:10 Begin execution of runSpecialJobTask
# >>>   2021/05/24 17:53:10 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs
# >>>   2021/05/24 17:53:10 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"e5c616eb-c2ae-44f5-94bf-41c9f196635c","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/24 17:53:10 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs/65_job_prep-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# >>>   2021/05/24 17:53:10 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml_compute_logs/65_job_prep-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# >>>   2021/05/24 17:53:10 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6;/azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"e5c616eb-c2ae-44f5-94bf-41c9f196635c","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/24 17:53:10 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/05/24 17:53:10 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-a271f132e67c01f3117d1bb721023495-3ad1e5a7cd2c6668-01 -t 56a05f73-be56-4f4e-a605-b2e8e9d3bab6 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/77142446-efa8-4b5a-8f5e-dfbd0da06bf7/job-1/56a05f73-be56-4f4e-a_ab0fdccf-1f93-458c-b2bd-dfaff15ba505/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6;/azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/demo-ent-ws/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/mounts/workspaceblobstore/azureml/56a05f73-be56-4f4e-a605-b2e8e9d3bab6-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"e5c616eb-c2ae-44f5-94bf-41c9f196635c","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/24 17:53:11 Attempt 1 of http call to https://westeurope.api.azureml.ms/history/v1.0/private/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourceGroups/demo/providers/Microsoft.MachineLearningServices/workspaces/demo-ent-ws/runs/56a05f73-be56-4f4e-a605-b2e8e9d3bab6/spans
# >>>   2021/05/24 17:53:14 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: bash: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so.5: no version information available (required by bash)
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:10.584486] Entering job preparation.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.036930] Starting job preparation.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.037002] Extracting the control code.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.176063] fetching and extracting the control code on master node.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.176150] Starting extract_project.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.176239] Starting to extract zip file.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.751420] Finished extracting zip file.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.953367] Using urllib.request Python 3.0 or later
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.953467] Start fetching snapshots.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.953535] Start fetching snapshot.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:12.953557] Retrieving project from snapshot: e5c616eb-c2ae-44f5-94bf-41c9f196635c
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 51
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:13.932970] Finished fetching snapshot.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:13.933009] Finished fetching snapshots.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:13.933018] Finished extract_project.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:13.946515] Finished fetching and extracting the control code.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:13.950245] downloadDataStore - Download from datastores if requested.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:13.951375] Start run_history_prep.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:14.010464] Entering context manager injector.
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: Acquired lockfile /tmp/56a05f73-be56-4f4e-a605-b2e8e9d3bab6-datastore.lock to downloading input data references
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:14.564883] downloadDataStore completed
# >>>   2021/05/24 17:53:14 runSpecialJobTask: preparation: [2021-05-24T17:53:14.569369] Job preparation is complete.
# >>>   2021/05/24 17:53:14 Execution of runSpecialJobTask completed
# >>>   2021/05/24 17:53:14 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/05/24 17:53:14 Process Exiting with Code:  0
# >>>   2021/05/24 17:53:14 All App Insights Logs was send successfully
# >>>
# 2021-05-24T17:53:15Z 127.0.0.1 slots=4 max-slots=4
# 2021-05-24T17:53:15Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt
# ===============================================================================================================
# bash: /azureml-envs/azureml_9cfcbdf246a71704d446a597691d2bad/lib/libtinfo.so.5: no version information available (required by bash)
# [2021-05-24T17:53:26.836967] Entering job release
# [2021-05-24T17:53:27.924360] Starting job release
# [2021-05-24T17:53:27.930398] Logging experiment finalizing status in history service.
# [2021-05-24T17:53:27.930580] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 177
# [2021-05-24T17:53:27.931039] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-24T17:53:27.931781] job release stage : execute_job_release starting...
# [2021-05-24T17:53:27.934624] job release stage : copy_batchai_cached_logs starting...
# [2021-05-24T17:53:27.941492] job release stage : copy_batchai_cached_logs completed...
# [2021-05-24T17:53:27.942019] Entering context manager injector.
# [2021-05-24T17:53:28.067060] job release stage : upload_datastore completed...
# [2021-05-24T17:53:28.120055] job release stage : send_run_telemetry starting...
# [2021-05-24T17:53:28.197350] job release stage : execute_job_release completed...
# [2021-05-24T17:53:28.371545] get vm size and vm region successfully.
# [2021-05-24T17:53:28.604218] get compute meta data successfully.
# [2021-05-24T17:53:28.814384] post artifact meta request successfully.
# [2021-05-24T17:53:28.850791] upload compute record artifact successfully.
# [2021-05-24T17:53:28.850914] job release stage : send_run_telemetry completed...
# [2021-05-24T17:53:28.851557] Job release is complete
#
# StepRun(train-step) Execution Summary
# ======================================
# StepRun( train-step ) Status: Finished
# {'runId': '56a05f73-be56-4f4e-a605-b2e8e9d3bab6', 'target': 'cluster', 'status': 'Completed', 'startTimeUtc': '2021-05-24T17:53:07.67494Z', 'endTimeUtc': '2021-05-24T17:53:36.702215Z', 'properties': {'ContentSnapshotId': 'e5c616eb-c2ae-44f5-94bf-41c9f196635c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '1d830300-c223-46ed-91f3-966f4e06617e', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '0c2f9780', 'azureml.pipelinerunid': 'e972bea0-a7c8-4af0-8644-ca63beb52a63', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--data-path', '$AZUREML_DATAREFERENCE_prepared_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'cluster', 'dataReferences': {'prepared_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/1976bc36-d674-4382-a3c8-f3336dfd807c/prepared_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment mlops-workshop-pipelines-20210524 Environment', 'version': 'Autosave_2021-05-24T15:14:27Z_2c4b275f', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge', 'defaults'], 'dependencies': ['python=3.6.2', 'pip<20.3', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas,fuse]', 'scikit-learn==0.20.3', 'pandas==0.25.3', 'joblib==0.13.2']}], 'name': 'azureml_9cfcbdf246a71704d446a597691d2bad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.56a05f73-be56-4f4e-a605-b2e8e9d3bab6/azureml-logs/55_azureml-execution-tvmps_36b3f3ebd83225e8bc2dc7d55ce1be36c710b2ebeba1bf09dc2117cd331435af_d.txt?sv=2019-02-02&sr=b&sig=TXyXk8IQeD%2FsqcyJ4tqkZZ ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'e972bea0-a7c8-4af0-8644-ca63beb52a63', 'status': 'Completed', 'startTimeUtc': '2021-05-24T17:47:52.925482Z', 'endTimeUtc': '2021-05-24T17:53:38.305968Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.e972bea0-a7c8-4af0-8644-ca63beb52a63/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=CJVeu7yU1Z3ZeUwsK9ZjV5tolXN4K6pJoTnGNHbekDU%3D&st=2021-05-24T17%3A43%3A39Z&se=2021-05-25T01%3A53%3A39Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.e972bea0-a7c8-4af0-8644-ca63beb52a63/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=%2FN5u7XCV73JzykWBZtk%2BL%2FlWbCc7nBgXKXddlEvdibk%3D&st=2021-05-24T17%3A43%3A39Z&se=2021-05-25T01%3A53%3A39Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://demoentws5367325393.blob.core.windows.net/azureml/ExperimentRun/dcid.e972bea0-a7c8-4af0-8644-ca63beb52a63/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=b2MKaCq8gLq5EwrWamEwkuwqKf0t0fUzkp4Xvky22Hw%3D&st=2021-05-24T17%3A43%3A39Z&se=2021-05-25T01%3A53%3A39Z&sp=r'}, 'submittedBy': 'Luca Zavarella'}
# 'Finished'

# %% [markdown]
# Alternatively, we can also publish the pipeline as a RESTful API Endpoint. In this case, you can specify the dataset upon invocation of the pipeline. This is nicely possible in the `Studio UI`, goto `Endpoints`, then `Pipeline Endpoints` and then select the pipeline. Once you hit the submit button, you can select the Dataset at the bottom of the window.

# %%
published_pipeline = pipeline.publish('mlops-multi-step-pipeline')
published_pipeline
# Out:
# Pipeline(Name: mlops-multi-step-pipeline,
# Id: 2140ab37-928e-4424-9f15-96bf7712d835,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/bcbf34a7-1936-4783-8840-8f324c37f354/resourceGroups/demo/providers/Microsoft.MachineLearningServices/workspaces/demo-ent-ws/PipelineRuns/PipelineSubmit/2140ab37-928e-4424-9f15-96bf7712d835)
